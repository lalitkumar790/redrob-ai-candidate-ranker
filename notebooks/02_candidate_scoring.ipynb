# %%
import sys
import os

project_root = os.path.abspath("..")
sys.path.append(project_root)

print(project_root)
# Out:
# c:\Users\Dell\redrob-ai-candidate-ranker

# %%
from src.utils.data_loader import load_candidates
from src.features.candidate_features import extract_candidate_features
from src.scoring.technical_scorer import calculate_technical_score

# %%
candidates = load_candidates("../data/candidates.jsonl")

# %%
for candidate in candidates[:10]:

    features = extract_candidate_features(candidate)

    score = calculate_technical_score(features)

    print(
        candidate["candidate_id"],
        score
    )
# Out:
# CAND_0000001 100
# CAND_0000002 10
# CAND_0000003 10
# CAND_0000004 5
# CAND_0000005 10
# CAND_0000006 5
# CAND_0000007 5
# CAND_0000008 15
# CAND_0000009 0
# CAND_0000010 20

# %%
candidate = candidates[0]

candidate["redrob_signals"]
# Out:
# {'profile_completeness_score': 86.9,
#  'signup_date': '2025-10-16',
#  'last_active_date': '2026-05-20',
#  'open_to_work_flag': True,
#  'profile_views_received_30d': 23,
#  'applications_submitted_30d': 2,
#  'recruiter_response_rate': 0.34,
#  'avg_response_time_hours': 177.8,
#  'skill_assessment_scores': {'NLP': 38.8,
#   'Image Classification': 64.8,
#   'Fine-tuning LLMs': 41.6,
#   'Speech Recognition': 53.7},
#  'connection_count': 356,
#  'endorsements_received': 35,
#  'notice_period_days': 60,
#  'expected_salary_range_inr_lpa': {'min': 18.7, 'max': 36.1},
#  'preferred_work_mode': 'onsite',
#  'willing_to_relocate': False,
#  'github_activity_score': 9.2,
#  'search_appearance_30d': 249,
#  'saved_by_recruiters_30d': 4,
#  'interview_completion_rate': 0.71,
#  'offer_acceptance_rate': 0.58,
#  'verified_email': True,
#  'verified_phone': True,
#  'linkedin_connected': False}

# %%
candidate["redrob_signals"].keys()
# Out:
# dict_keys(['profile_completeness_score', 'signup_date', 'last_active_date', 'open_to_work_flag', 'profile_views_received_30d', 'applications_submitted_30d', 'recruiter_response_rate', 'avg_response_time_hours', 'skill_assessment_scores', 'connection_count', 'endorsements_received', 'notice_period_days', 'expected_salary_range_inr_lpa', 'preferred_work_mode', 'willing_to_relocate', 'github_activity_score', 'search_appearance_30d', 'saved_by_recruiters_30d', 'interview_completion_rate', 'offer_acceptance_rate', 'verified_email', 'verified_phone', 'linkedin_connected'])

# %%
from src.scoring.signal_scorer import calculate_signal_score

# %%
import random

for idx in random.sample(range(len(candidates)), 10):

    candidate = candidates[idx]

    score = calculate_signal_score(
        candidate["redrob_signals"]
    )

    print(
        candidate["candidate_id"],
        score
    )
# Out:
# CAND_0016116 100
# CAND_0037248 100
# CAND_0092889 100
# CAND_0035848 100
# CAND_0028072 100
# CAND_0021177 100
# CAND_0080768 100
# CAND_0024791 100
# CAND_0091317 100
# CAND_0099337 100

# %%
from src.scoring.signal_scorer import calculate_signal_score

candidate = candidates[0]
signals = candidate["redrob_signals"]

for key, value in signals.items():
    print(f"{key}: {value}")
# Out:
# profile_completeness_score: 86.9
# signup_date: 2025-10-16
# last_active_date: 2026-05-20
# open_to_work_flag: True
# profile_views_received_30d: 23
# applications_submitted_30d: 2
# recruiter_response_rate: 0.34
# avg_response_time_hours: 177.8
# skill_assessment_scores: {'NLP': 38.8, 'Image Classification': 64.8, 'Fine-tuning LLMs': 41.6, 'Speech Recognition': 53.7}
# connection_count: 356
# endorsements_received: 35
# notice_period_days: 60
# expected_salary_range_inr_lpa: {'min': 18.7, 'max': 36.1}
# preferred_work_mode: onsite
# willing_to_relocate: False
# github_activity_score: 9.2
# search_appearance_30d: 249
# saved_by_recruiters_30d: 4
# interview_completion_rate: 0.71
# offer_acceptance_rate: 0.58
# verified_email: True
# verified_phone: True
# linkedin_connected: False

# %%
scores = []

for candidate in candidates[:1000]:
    score = calculate_signal_score(
        candidate["redrob_signals"]
    )
    scores.append(score)

print("Min:", min(scores))
print("Max:", max(scores))
print("Average:", sum(scores)/len(scores))
# Out:
# Min: 100
# Max: 100
# Average: 100.0

# %%
github_scores = []
profile_scores = []
search_scores = []
saved_scores = []

for candidate in candidates[:5000]:

    signals = candidate["redrob_signals"]

    github_scores.append(
        signals.get("github_activity_score", 0)
    )

    profile_scores.append(
        signals.get("profile_completeness_score", 0)
    )

    search_scores.append(
        signals.get("search_appearance_30d", 0)
    )

    saved_scores.append(
        signals.get("saved_by_recruiters_30d", 0)
    )

print("GitHub")
print(min(github_scores), max(github_scores))

print("Profile")
print(min(profile_scores), max(profile_scores))

print("Search")
print(min(search_scores), max(search_scores))

print("Saved")
print(min(saved_scores), max(saved_scores))
# Out:
# GitHub
# -1 96.9
# Profile
# 25.0 98.0
# Search
# 0 949
# Saved
# 0 53

# %%
import importlib

import src.scoring.signal_scorer

importlib.reload(
    src.scoring.signal_scorer
)

from src.scoring.signal_scorer import (
    calculate_signal_score
)

# %%
scores = []

for candidate in candidates[:1000]:

    score = calculate_signal_score(
        candidate["redrob_signals"]
    )

    scores.append(score)

print("Min:", min(scores))
print("Max:", max(scores))
print("Average:", round(sum(scores)/len(scores),2))
# Out:
# Min: 18.79
# Max: 80.95
# Average: 45.25

# %%
titles = {}

for candidate in candidates:

    title = candidate["profile"][
        "current_title"
    ]

    titles[title] = (
        titles.get(title, 0) + 1
    )

sorted(
    titles.items(),
    key=lambda x: x[1],
    reverse=True
)[:50]
# Out:
# [('Business Analyst', 5833),
#  ('HR Manager', 5830),
#  ('Mechanical Engineer', 5791),
#  ('Accountant', 5764),
#  ('Project Manager', 5754),
#  ('Customer Support', 5750),
#  ('Operations Manager', 5744),
#  ('Content Writer', 5727),
#  ('Sales Executive', 5713),
#  ('Civil Engineer', 5702),
#  ('Graphic Designer', 5689),
#  ('Marketing Manager', 5524),
#  ('Software Engineer', 3450),
#  ('Full Stack Developer', 2873),
#  ('Cloud Engineer', 2836),
#  ('Java Developer', 2809),
#  ('.NET Developer', 2788),
#  ('DevOps Engineer', 2787),
#  ('Mobile Developer', 2757),
#  ('Frontend Engineer', 2738),
#  ('QA Engineer', 2682),
#  ('Analytics Engineer', 764),
#  ('Data Engineer', 744),
#  ('Data Analyst', 728),
#  ('Backend Engineer', 704),
#  ('Senior Data Engineer', 687),
#  ('Senior Software Engineer', 653),
#  ('ML Engineer', 167),
#  ('AI Research Engineer', 153),
#  ('Data Scientist', 145),
#  ('Senior Software Engineer (ML)', 142),
#  ('Computer Vision Engineer', 132),
#  ('Junior ML Engineer', 131),
#  ('AI Specialist', 130),
#  ('Recommendation Systems Engineer', 26),
#  ('Machine Learning Engineer', 24),
#  ('Applied ML Engineer', 23),
#  ('Search Engineer', 23),
#  ('AI Engineer', 21),
#  ('Senior Data Scientist', 19),
#  ('NLP Engineer', 14),
#  ('Senior NLP Engineer', 6),
#  ('Senior Machine Learning Engineer', 6),
#  ('Staff Machine Learning Engineer', 6),
#  ('Senior AI Engineer', 4),
#  ('Senior Applied Scientist', 4),
#  ('Lead AI Engineer', 3)]

# %%
from src.scoring.ai_relevance_scorer import (
    calculate_ai_relevance_score
)

scores = []

for candidate in candidates[:5000]:

    score = calculate_ai_relevance_score(
        candidate
    )

    scores.append(score)

print("Min:", min(scores))
print("Max:", max(scores))
print("Average:", round(sum(scores)/len(scores),2))
# Out:
# Min: 0
# Max: 100
# Average: 8.45

# %%
from src.scoring.experience_scorer import (
    calculate_experience_score
)

scores = []

for candidate in candidates[:5000]:

    score = calculate_experience_score(
        candidate
    )

    scores.append(score)

print("Min:", min(scores))
print("Max:", max(scores))
print("Average:", round(sum(scores)/len(scores),2))
# Out:
# Min: 4.0
# Max: 60
# Average: 30.98

# %%
candidate = next(
    c for c in candidates
    if c["candidate_id"] == "CAND_0000847"
)

print(
    candidate["profile"]["current_title"]
)

print("\nSkills:\n")

for skill in candidate["skills"]:
    print(skill["name"])
# Out:
# HR Manager
#
# Skills:
#
# Accounting
# Computer Vision
# Apache Flink
# Docker
# Figma
# GCP
# JavaScript
# Pinecone
# Information Retrieval
# Vector Search
# RAG
# Prompt Engineering
# FAISS
# Sentence Transformers
# Hugging Face Transformers
# LLMs
# Semantic Search
# Recommendation Systems
# Embeddings

# %%
candidate = next(
    c for c in candidates
    if c["candidate_id"] == "CAND_0003324"
)

print(candidate["profile"])

print("\nCAREER HISTORY\n")

for job in candidate["career_history"]:
    print(job["title"])
# Out:
# {'anonymized_name': 'Naina Mehta', 'headline': 'Mechanical Engineer | Exploring AI & GenAI applications', 'summary': "Mechanical Engineer with 10.8+ years of experience driving outcomes in my domain. I have built strong functional expertise in the typical responsibilities of the role, including team management, stakeholder communication, and project delivery. Recently I've been excited about how AI and GenAI tools can augment my work. I've been taking online courses on RAG and vector databases, experimenting with LangChain and the OpenAI API for side projects, and exploring how LLMs can streamline workflows in my current function. Open to roles that combine my existing domain experience with emerging AI technologies — I think the most interesting opportunities are at this intersection. Looking for positions where I can contribute both my functional expertise and grow my AI capabilities.", 'location': 'Hyderabad, Telangana', 'country': 'India', 'years_of_experience': 10.8, 'current_title': 'Mechanical Engineer', 'current_company': 'Pied Piper', 'current_company_size': '11-50', 'current_industry': 'Software'}
#
# CAREER HISTORY
#
# Mechanical Engineer
# Operations Manager
# Graphic Designer
# Mechanical Engineer

# %%
candidate = next(
    c for c in candidates
    if c["candidate_id"] == "CAND_0001610"
)

print(candidate["profile"]["summary"])

print("\nCAREER HISTORY\n")

for job in candidate["career_history"]:
    print(job["title"])

print("\nASSESSMENTS\n")

print(
    candidate["redrob_signals"][
        "skill_assessment_scores"
    ]
)
# Out:
# Machine learning engineer with 5.2 years of experience building ML-powered features in production. Strong background in NLP, recommendation systems, and applied AI; comfortable across the ML stack from feature engineering through deployment. Recently, I built our semantic search infrastructure from scratch — sentence-transformers, FAISS, the works. I've spent enough time debugging production ranking issues to know which signals matter and which are noise. My academic background is in CS/ML but my main learning has come from shipping real systems and seeing what holds up under production load. Open to senior IC roles in applied ML or AI engineering, ideally at product companies where I'd own a meaningful piece of the ML stack.
#
# CAREER HISTORY
#
# Machine Learning Engineer
# Senior Data Scientist
# Machine Learning Engineer
#
# ASSESSMENTS
#
# {}

# %%
candidate = next(
    c for c in candidates
    if c["candidate_id"] == "CAND_0003324"
)

print(candidate["profile"]["current_title"])

print("\nASSESSMENT SCORES:\n")

print(
    candidate["redrob_signals"][
        "skill_assessment_scores"
    ]
)
# Out:
# Mechanical Engineer
#
# ASSESSMENT SCORES:
#
# {'GANs': 50.0}

# %%
candidate = next(
    c for c in candidates
    if c["candidate_id"] == "CAND_0001610"
)

print(candidate["profile"]["current_title"])

print("\nASSESSMENT SCORES:\n")

print(
    candidate["redrob_signals"][
        "skill_assessment_scores"
    ]
)
# Out:
# Machine Learning Engineer
#
# ASSESSMENT SCORES:
#
# {}

# %%
top_ids = [
    "CAND_0001930",
    "CAND_0001610",
    "CAND_0003324"
]

for cid in top_ids:

    candidate = next(
        c for c in candidates
        if c["candidate_id"] == cid
    )

    print("=" * 80)

    print("ID:", cid)

    print(
        "TITLE:",
        candidate["profile"]["current_title"]
    )

    print(
        "EXPERIENCE:",
        candidate["profile"]["years_of_experience"]
    )

    print("\nTOP SKILLS:")

    for skill in candidate["skills"][:10]:
        print("-", skill["name"])

    print("\nSUMMARY:")

    print(
        candidate["profile"]["summary"][:500]
    )

    print("\nCAREER HISTORY:")

    for job in candidate["career_history"]:
        print("-", job["title"])

    print()
# Out:
# ================================================================================
# ID: CAND_0001930
# TITLE: Senior Software Engineer (ML)
# EXPERIENCE: 6.9
#
# TOP SKILLS:
# - Machine Learning
# - GraphQL
# - Webpack
# - CSS
# - Kubeflow
# - NLP
# - Embeddings
# - Statistical Modeling
# - BentoML
# - Milvus
#
# SUMMARY:
# Data scientist / ML engineer with 6.9 years of experience in applied machine learning. Worked across predictive modeling, NLP, analytics, and lightweight deployment workflows. My current role is split between dashboarding/analytics and shipping production ML models. I'm strongest at the modeling and analysis side; comfortable with Python, scikit-learn, pandas, and standard MLOps tooling, but I'm still building depth on the engineering and infra side of production ML. I want to grow into senior A
#
# CAREER HISTORY:
# - Senior Software Engineer (ML)
# - Computer Vision Engineer
# - Data Scientist
#
# ================================================================================
# ID: CAND_0001610
# TITLE: Machine Learning Engineer
# EXPERIENCE: 3.0
#
# TOP SKILLS:
# - Speech Recognition
# - Haystack
# - Deep Learning
# - Kubeflow
# - Pinecone
# - Salesforce CRM
# - Feature Engineering
# - scikit-learn
# - Fine-tuning LLMs
# - Data Science
#
# SUMMARY:
# Machine learning engineer with 5.2 years of experience building ML-powered features in production. Strong background in NLP, recommendation systems, and applied AI; comfortable across the ML stack from feature engineering through deployment. Recently, I built our semantic search infrastructure from scratch — sentence-transformers, FAISS, the works. I've spent enough time debugging production ranking issues to know which signals matter and which are noise. My academic background is in CS/ML but m
#
# CAREER HISTORY:
# - Machine Learning Engineer
# - Senior Data Scientist
# - Machine Learning Engineer
#
# ================================================================================
# ID: CAND_0003324
# TITLE: Mechanical Engineer
# EXPERIENCE: 10.8
#
# TOP SKILLS:
# - BigQuery
# - PowerPoint
# - GANs
# - Kafka
# - Airflow
# - GCP
# - Project Management
# - Docker
# - Semantic Search
# - LLMs
#
# SUMMARY:
# Mechanical Engineer with 10.8+ years of experience driving outcomes in my domain. I have built strong functional expertise in the typical responsibilities of the role, including team management, stakeholder communication, and project delivery. Recently I've been excited about how AI and GenAI tools can augment my work. I've been taking online courses on RAG and vector databases, experimenting with LangChain and the OpenAI API for side projects, and exploring how LLMs can streamline workflows in
#
# CAREER HISTORY:
# - Mechanical Engineer
# - Operations Manager
# - Graphic Designer
# - Mechanical Engineer

# %%
candidate = next(
    c for c in candidates
    if c["candidate_id"] == "CAND_0001980"
)

print(candidate["profile"]["summary"])

print("\nSKILLS\n")

for skill in candidate["skills"]:
    print(skill["name"])

print("\nCAREER HISTORY\n")

for job in candidate["career_history"]:
    print(job["title"])
# Out:
# Operations Manager with 8.7+ years of experience driving outcomes in my domain. I have built strong functional expertise in the typical responsibilities of the role, including team management, stakeholder communication, and project delivery. Recently I've been excited about how AI and GenAI tools can augment my work. I've been taking online courses on RAG and vector databases, experimenting with LangChain and the OpenAI API for side projects, and exploring how LLMs can streamline workflows in my current function. Open to roles that combine my existing domain experience with emerging AI technologies — I think the most interesting opportunities are at this intersection. Looking for positions where I can contribute both my functional expertise and grow my AI capabilities.
#
# SKILLS
#
# SEO
# Spark
# REST APIs
# Marketing
# Snowflake
# Sales
# Photoshop
# HTML
# SQL
# Speech Recognition
# Information Retrieval
# Pinecone
# Fine-tuning LLMs
# Prompt Engineering
# LangChain
# Embeddings
# FAISS
# RAG
# LLMs
# Hugging Face Transformers
# Recommendation Systems
# Sentence Transformers
#
# CAREER HISTORY
#
# Operations Manager
# Graphic Designer
# Project Manager
# Project Manager
